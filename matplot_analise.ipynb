# %%
import pandas as pd
import matplotlib.pyplot as plt

df_soma = pd.read_excel('./.streamlit/somas_total_2013_2024.xlsx')
df_tipo = pd.read_excel('./.streamlit/tipo_residuos_total.xlsx')
df_mensal = pd.read_excel('./streamlit/')

display(df_soma, df_tipo)
# Out:
#      ano  soma_total
# 0   2013  6219039.46
# 1   2014  5888181.20
# 2   2015  5750715.95
# 3   2016  5452934.86
# 4   2017  5620564.34
# 5   2018  5688310.14
# 6   2019  5629081.10
# 7   2020  5722927.00
# 8   2021  3421379.44
# 9   2023  3452796.87
# 10  2024  3515678.96
#              tipo_residuo  total_2013  total_2014  total_2015  total_2016  \
# 0      alimentos_vencidos       14.90       10.70        0.00        0.00
# 1                 animais       94.60       93.67      111.50       85.56
# 2       nao_classificados        0.00        0.00        0.00        0.00
# 3                diversos   329755.66   334019.89   348969.64   292103.68
# 4           diversos_emae      328.48        0.00        0.00        6.70
# 5              domiciliar  3831455.19  3802438.73  3801404.45  3583509.78
# 6      entulho_apreendido      162.32        0.00       78.46        9.17
# 7         entulho_predial        0.00        0.00        0.00        0.00
# ...
